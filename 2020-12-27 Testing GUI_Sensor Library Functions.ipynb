# %%
import numpy as np
from src.sources.video import VideoSource, YSource

# %%
video = YSource()
video.start()

# %%
import matplotlib.pyplot as plt
grabbed, frame = video.read()
plt.imshow(frame)

# %%
from src.visualisers.spectrogram_gui import decompose

# %%
[A, H, V, D] = decompose(frame.astype(np.int16))

# %%
A.shape
# Out:
# (479, 639)

# %%
plt.imshow(A)

# %%
plt.imshow(A[::2, ::2])

# %%
A[::2, ::2].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-080c0e8c4f10> in <module>
# ----> 1 A[::2, ::2].shape
#
# NameError: name 'A' is not defined
