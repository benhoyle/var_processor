# %% [markdown]
# See here - https://towardsdatascience.com/the-easiest-way-to-download-youtube-videos-using-python-2640958318ab.
#
# PyTube seems to be maintained now - install via pip.

# %%
from pytube import YouTube
# misc
import os
import shutil
import math
import datetime
# plots
import matplotlib.pyplot as plt
# %matplotlib inline
# image operation
import cv2

# %%
# Load a video via URL
video = YouTube("https://www.youtube.com/watch?v=ZOnzBSWIAzo")

# %%
# View the available video streams
video.streams.all()
# Out:
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a list, all() is useless).
#   """Entry point for launching an IPython kernel.
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">,
#  <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">,
#  <Stream: itag="242" mime_type="video/webm" res="240p" fps="30fps" vcodec="vp9" progressive="False" type="video">,
#  <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">,
#  <Stream: itag="278" mime_type="video/webm" res="144p" fps="30fps" vcodec="vp9" progressive="False" type="video">,
#  <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">,
#  <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">,
#  <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">,
#  <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
# Filter to show only mp4 streams
video.streams.filter(file_extension = "mp4").all()
# Out:
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a list, all() is useless).
#   """Entry point for launching an IPython kernel.
# [<Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">,
#  <Stream: itag="133" mime_type="video/mp4" res="240p" fps="30fps" vcodec="avc1.4d4015" progressive="False" type="video">,
#  <Stream: itag="160" mime_type="video/mp4" res="144p" fps="30fps" vcodec="avc1.4d400c" progressive="False" type="video">,
#  <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">]

# %%
# Download a video stream using the itag ID
video.streams.get_by_itag(18).download()
# Out:
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '/home/ben/Projects/var_processor/Frege Russell & Modern Logic - A J Ayer.mp4'

# %%
# Define a wrapper class for accessing frame information
class FrameExtractor():
    '''
    Class used for extracting frames from a video file.
    '''
    def __init__(self, video_path):
        self.video_path = video_path
        self.vid_cap = cv2.VideoCapture(video_path)
        self.n_frames = int(self.vid_cap.get(cv2.CAP_PROP_FRAME_COUNT))
        self.fps = int(self.vid_cap.get(cv2.CAP_PROP_FPS))
        
    def get_video_duration(self):
        duration = self.n_frames/self.fps
        print(f'Duration: {datetime.timedelta(seconds=duration)}')
        
    def get_n_images(self, every_x_frame):
        n_images = math.floor(self.n_frames / every_x_frame) + 1
        print(f'Extracting every {every_x_frame} (nd/rd/th) frame would result in {n_images} images.')
        
    def extract_frames(self, every_x_frame, img_name, dest_path=None, img_ext = '.jpg'):
        if not self.vid_cap.isOpened():
            self.vid_cap = cv2.VideoCapture(self.video_path)
        
        if dest_path is None:
            dest_path = os.getcwd()
        else:
            if not os.path.isdir(dest_path):
                os.mkdir(dest_path)
                print(f'Created the following directory: {dest_path}')
        
        frame_cnt = 0
        img_cnt = 0

        while self.vid_cap.isOpened():
            
            success,image = self.vid_cap.read() 
            
            if not success:
                break
            
            if frame_cnt % every_x_frame == 0:
                img_path = os.path.join(dest_path, ''.join([img_name, '_', str(img_cnt), img_ext]))
                cv2.imwrite(img_path, image)  
                img_cnt += 1
                
            frame_cnt += 1
        
        self.vid_cap.release()
        cv2.destroyAllWindows()

# %%
path = '/home/ben/Projects/var_processor/Frege Russell & Modern Logic - A J Ayer.mp4'

# %%
fe = FrameExtractor(path)

# %%
print(fe.n_frames, fe.fps)
# Out:
# 75694 29

# %%
fe.get_video_duration()
# Out:
# Duration: 0:43:30.137931

# %%
fe.get_n_images(every_x_frame=1000)
# Out:
# Extracting every 1000 (nd/rd/th) frame would result in 76 images.

# %% [markdown]
# So what do we need?
# * A way to get synchronised audio and video streams.
# * A way to get subtitles/captions.
# * A possible way to stream the data rather than download.
# * A way to search and access a large number of videos.
#
# Let's start with the PyTube docs - https://python-pytube.readthedocs.io/en/latest/user/quickstart.html#working-with-streams.

# %% [markdown]
# ## Audio
#
# We have separate audio and video streams for mp4. We also have opus audio streams.
#
# We download and process the audio separately, using the timing information to synchronise.

# %%
video.streams.filter(only_audio=True).all()
# Out:
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a list, all() is useless).
#   """Entry point for launching an IPython kernel.
# [<Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">,
#  <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">,
#  <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">,
#  <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %% [markdown]
# ## Captions
#
# PyTube also supports getting the caption information - but only videos with captions with have this.

# %%
video.captions.all()
# Out:
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   """Entry point for launching an IPython kernel.
# [<Caption lang="English (auto-generated)" code="a.en">]

# %%
caption = video.captions.get_by_language_code('a.en')
# Out:
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   """Entry point for launching an IPython kernel.

# %%
caption.xml_captions
# Out:
# /home/ben/anaconda3/envs/ml_platform_3_7/lib/python3.7/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# '<?xml version="1.0" encoding="utf-8" ?><transcript><text start="0" dur="6.019">[Music]</text><text start="6.62" dur="5.83">a great deal of the philosophy that&amp;#39;s</text><text start="10.92" dur="4.2">going on today in the english-speaking</text><text start="12.45" dur="4.26">world in fact probably most of it can be</text><text start="15.12" dur="4.05">traced back through intermediate</text><text start="16.71" dur="4.34">developments to the work of two men got</text><text start="19.17" dur="4.41">flogged Frager and Bertrand Russell</text><text start="21.05" dur="4.63">working for the most part independently</text><text start="23.58" dur="4.38">of each other they laid the foundations</text><text start="25.68" dur="4.08">of modern logic but more than that</text><text start="27.96" dur="3.93">although the work on which they began</text><text start="29.76" dur="4.17">concerned chiefly the principles of</text><text start="31.89" dur="4.829">mathematics and the relationship between</text><text start="33.93" dur="5.129">mathematics and logic its implications</text><text start="36.719" dur="4.291">went so wide but in the course of time</text><text start="39.059" dur="5.16">it came to have a profound influence on</text><text start="41.01" dur="4.77">philosophy in general exactly the same</text><text start="44.219" dur="3.601">happen with the philosopher who most</text><text start="45.78" dur="5.07">obviously and directly followed on from</text><text start="47.82" dur="5.16">them named David Ben Stein Vixen Stein</text><text start="50.85" dur="4.709">started by developing Russell&amp;#39;s &amp;amp;</text><text start="52.98" dur="4.29">frege&amp;#39;s work in mathematical logic but</text><text start="55.559" dur="4.02">he ended up acquiring an influence of</text><text start="57.27" dur="5.039">large on 20th century philosophy which</text><text start="59.579" dur="3.96">is second to nobody in this program</text><text start="62.309" dur="3.63">without going into any of the</text><text start="63.539" dur="4.381">technicalities of mathematics or logic I</text><text start="65.939" dur="4.201">want to give some indication of how</text><text start="67.92" dur="4.949">fragrant and Russell came to have this</text><text start="70.14" dur="4.68">enormous influence on 20th century fork</text><text start="72.869" dur="3.601">and to say a little about some of the</text><text start="74.82" dur="4.5">more recent individuals and groups</text><text start="76.47" dur="4.8">who&amp;#39;ve come under that influence but</text><text start="79.32" dur="4.92">first a word about the individuals</text><text start="81.27" dur="5.94">themselves Frager a German was born in</text><text start="84.24" dur="5.22">1848 and spent his entire working life</text><text start="87.21" dur="4.08">in comparative obscurity in the</text><text start="89.46" dur="4.68">mathematics department of the University</text><text start="91.29" dur="4.95">of Vienna not until after his death that</text><text start="94.14" dur="4.979">his name to come down at all widely even</text><text start="96.24" dur="5.94">among philosophers his first major work</text><text start="99.119" dur="5.36">published in 1879 was called big</text><text start="102.18" dur="4.649">wishlist and I&amp;#39;m afraid even the English</text><text start="104.479" dur="4.331">translation keeps the German title</text><text start="106.829" dur="4.47">because there&amp;#39;s no satisfactory English</text><text start="108.81" dur="5.309">for it it means something like the</text><text start="111.299" dur="4.441">putting of concepts into notation and</text><text start="114.119" dur="2.061">we&amp;#39;ll begin to see later what that&amp;#39;s</text><text start="115.74" dur="4.35">about</text><text start="116.18" dur="6.1">his next major work published in 1884 is</text><text start="120.09" dur="4.62">called in English the foundations of</text><text start="122.28" dur="5.1">arithmetic he went on producing</text><text start="124.7 ...

# %%
dir(caption)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'code',
#  'download',
#  'float_to_srt_time_format',
#  'generate_srt_captions',
#  'name',
#  'url',
#  'xml_caption_to_srt',
#  'xml_captions']

# %%
srt_captions = caption.generate_srt_captions()
print(srt_captions)
# Out:
# 1
# 00:00:00,000 --> 00:00:06,019
# [Music]
#
# 2
# 00:00:06,620 --> 00:00:12,450
# a great deal of the philosophy that's
#
# 3
# 00:00:10,920 --> 00:00:15,120
# going on today in the english-speaking
#
# 4
# 00:00:12,450 --> 00:00:16,710
# world in fact probably most of it can be
#
# 5
# 00:00:15,120 --> 00:00:19,170
# traced back through intermediate
#
# 6
# 00:00:16,710 --> 00:00:21,050
# developments to the work of two men got
#
# 7
# 00:00:19,170 --> 00:00:23,580
# flogged Frager and Bertrand Russell
#
# 8
# 00:00:21,050 --> 00:00:25,680
# working for the most part independently
#
# 9
# 00:00:23,580 --> 00:00:27,960
# of each other they laid the foundations
#
# 10
# 00:00:25,680 --> 00:00:29,760
# of modern logic but more than that
#
# 11
# 00:00:27,960 --> 00:00:31,890
# although the work on which they began
#
# 12
# 00:00:29,760 --> 00:00:33,930
# concerned chiefly the principles of
#
# 13
# 00:00:31,890 --> 00:00:36,719
# mathematics and the relationship between
#
# 14
# 00:00:33,930 --> 00:00:39,059
# mathematics and logic its implications
#
# 15
# 00:00:36,719 --> 00:00:41,010
# went so wide but in the course of time
#
# 16
# 00:00:39,059 --> 00:00:44,219
# it came to have a profound influence on
#
# 17
# 00:00:41,010 --> 00:00:45,780
# philosophy in general exactly the same
#
# 18
# 00:00:44,219 --> 00:00:47,820
# happen with the philosopher who most
#
# 19
# 00:00:45,780 --> 00:00:50,850
# obviously and directly followed on from
#
# 20
# 00:00:47,820 --> 00:00:52,980
# them named David Ben Stein Vixen Stein
#
# 21
# 00:00:50,850 --> 00:00:55,559
# started by developing Russell's &
#
# 22
# 00:00:52,980 --> 00:00:57,270
# frege's work in mathematical logic but
#
# 23
# 00:00:55,559 --> 00:00:59,579
# he ended up acquiring an influence of
#
# 24
# 00:00:57,270 --> 00:01:02,309
# large on 20th century philosophy which
#
# 25
# 00:00:59,579 --> 00:01:03,539
# is second to nobody in this program
#
# 26
# 00:01:02,309 --> 00:01:05,939
# without going into any of the
#
# 27
# 00:01:03,539 --> 00:01:07,920
# technicalities of mathematics or logic I
#
# 28
# 00:01:05,939 --> 00:01:10,140
# want to give some indication of how
#
# 29
# 00:01:07,920 --> 00:01:12,869
# fragrant and Russell came to have this
#
# 30
# 00:01:10,140 --> 00:01:14,820
# enormous influence on 20th century fork
#
# 31
# 00:01:12,869 --> 00:01:16,470
# and to say a little about some of the
#
# 32
# 00:01:14,820 --> 00:01:19,320
# more recent individuals and groups
#
# 33
# 00:01:16,470 --> 00:01:21,270
# who've come under that influence but
#
# 34
# 00:01:19,320 --> 00:01:24,240
# first a word about the individuals
#
# 35
# 00:01:21,270 --> 00:01:27,210
# themselves Frager a German was born in
#
# 36
# 00:01:24,240 --> 00:01:29,460
# 1848 and spent his entire working life
#
# 37
# 00:01:27,210 --> 00:01:31,290
# in comparative obscurity in the
#
# 38
# 00:01:29,460 --> 00:01:34,140
# mathematics department of the University
#
# 39
# 00:01:31,290 --> 00:01:36,240
# of Vienna not until after his death that
#
# 40
# 00:01:34,140 --> 00:01:39,119
# his name to come down at all widely even
#
# 41
# 00:01:36,240 --> 00:01:42,180
# among philosophers his first major work
#
# 42
# 00:01:39,119 --> 00:01:44,479
# published in 1879 was called big
#
# 43
# 00:01:42,180 --> 00:01:46,829
# wishlist and I'm afraid even the English
#
# 44
# 00:01:44,479 --> 00:01:48,810
# translation keeps the German title
#
# 45
# 00:01:46,829 --> 00:01:51,299
# because there's no satisfactory English
#
# 46
# 00:01:48,810 --> 00:01:54,119
# for it it means something like the
#
# 47
# 00:01:51,299 --> 00:01:55,740
# putting of concepts into notation and
#
# 48
# 00:01:54,119 --> 00:01:56,180
# we'll begin to see later what that's
#
# 49
# 00:01:55,740 --> 00:02:00,090
# about
#
# 50
# 00:01:56,180 --> 00:02:02,280
# his next major work published in 1884 is
#
# 51
# 00:02:00,090 --> 00:02:04,710
# called in English the foundations of
#
# 52
# 00:02:02,280 --> 00:02:07,380
# arithmetic he went on producing
#
# 53
# 00:02:04,710 --> 00:02:11,009
# important and original work most notably
#
# 54
# 00:02:07,380 --> 00:02:12,710
# in 1893 and 1903 two volumes of the
#
# 55
# 00:02:11,009 --> 00:02:15,340
# projected larger work
#
# 56
# 00:02:12,710 --> 00:02:17,980
# in English the basic laws of arithmetic
#
# 57
# 00:02:15,340 --> 00:02:20,660
# but it was all one of such depth
#
# 58
# 00:02:17,980 --> 00:02:23,120
# difficulty that his work in general
#
# 59
# 00:02:20,660 --> 00:02:25,120
# remained very largely unknown until
#
# 60
# 00:02:23,120 --> 00:02:29,420
# Bertrand Russell drew attention to it in
#
# 61
# 00:02:25,120 --> 00:02:31,550
# 1903 Russell was a totally different
#
# 62
# 00:02:29,420 --> 00:02:33,950
# sort of person grandson of the British
#
# 63
# 00:02:31,550 --> 00:02:36,050
# prime minister from whom he was later by
#
# 64
# 00:02:33,950 --> 00:02:38,420
# his elder brother to inherit an earldom
#
# 65
# 00:02:36,050 --> 00:02:40,670
# he was always prominent on the political
#
# 66
# 00:02:38,420 --> 00:02:42,890
# and social scene as well as in
#
# 67
# 00:02:40,670 --> 00:02:45,470
# philosophy in fact a famous public
#
# 68
# 00:02:42,890 --> 00:02:47,420
# figure or his life he did a tremendous
#
# 69
# 00:02:45,470 --> 00:02:50,480
# amount of popular writing and journalism
#
# 70
# 00:02:47,420 --> 00:02:52,580
# and broadcasting which influenced social
#
# 71
# 00:02:50,480 --> 00:02:54,920
# attitudes among successive generations
#
# 72
# 00:02:52,580 --> 00:02:56,900
# of British people I think this is
#
# 73
# 00:02:54,920 --> 00:02:59,120
# obscured for many the fact of the true
#
# 74
# 00:02:56,900 --> 00:03:01,640
# foundations of his fame as a philosopher
#
# 75
# 00:02:59,120 --> 00:03:03,980
# lying contributions to mathematical
#
# 76
# 00:03:01,640 --> 00:03:07,430
# logic of a highly professional and
#
# 77
# 00:03:03,980 --> 00:03:10,820
# technical character he was born in 1872
#
# 78
# 00:03:07,430 --> 00:03:12,920
# and little 1970 it was politically
#
# 79
# 00:03:10,820 --> 00:03:14,810
# active almost to the end though the
#
# 80
# 00:03:12,920 --> 00:03:18,020
# great bulk of his philosophical work was
#
# 81
# 00:03:14,810 --> 00:03:20,210
# done by the 1920 here to discuss the
#
# 82
# 00:03:18,020 --> 00:03:22,730
# work of these two men and some of its
#
# 83
# 00:03:20,210 --> 00:03:24,650
# influences down to our own day is one of
#
# 84
# 00:03:22,730 --> 00:03:27,080
# the most famous philosophers in our time
#
# 85
# 00:03:24,650 --> 00:03:29,420
# a jair who has written a great deal
#
# 86
# 00:03:27,080 --> 00:03:32,390
# about Russell including the best short
#
# 87
# 00:03:29,420 --> 00:03:34,310
# introductory book on Russell's work but
#
# 88
# 00:03:32,390 --> 00:03:36,650
# that's right let's start with Frager as
#
# 89
# 00:03:34,310 --> 00:03:39,740
# being the earliest figure when he began
#
# 90
# 00:03:36,650 --> 00:03:44,240
# what was it he was trying to do well he
#
# 91
# 00:03:39,740 --> 00:03:46,880
# was trying to make up what he thought
#
# 92
# 00:03:44,240 --> 00:03:49,100
# well deficiencies in arithmetic he
#
# 93
# 00:03:46,880 --> 00:03:52,580
# thought that mathematical statements as
#
# 94
# 00:03:49,100 --> 00:03:54,110
# they were expressing his day were not
#
# 95
# 00:03:52,580 --> 00:03:55,730
# sufficiently precise and that
#
# 96
# 00:03:54,110 --> 00:03:58,460
# mathematical proofs were not
#
# 97
# 00:03:55,730 --> 00:04:00,590
# sufficiently rigorous and so he began by
#
# 98
# 00:03:58,460 --> 00:04:02,750
# trying to develop a notation the belief
#
# 99
# 00:04:00,590 --> 00:04:05,210
# shift he referred to in which to become
#
# 100
# 00:04:02,750 --> 00:04:08,390
# good in which this will be remedied and
#
# 101
# 00:04:05,210 --> 00:04:10,820
# occasions to show exactly what measure
#
# 102
# 00:04:08,390 --> 00:04:12,950
# met men medical statement stated and
#
# 103
# 00:04:10,820 --> 00:04:15,530
# exactly what their proof statistically
#
# 104
# 00:04:12,950 --> 00:04:18,049
# was first made obvious how one step in
#
# 105
# 00:04:15,530 --> 00:04:20,210
# the proof succeeded another and this is
#
# 106
# 00:04:18,049 --> 00:04:23,600
# deficient in mathematics in his time
#
# 107
# 00:04:20,210 --> 00:04:26,330
# applying even to Euclid where there were
#
# 108
# 00:04:23,600 --> 00:04:28,280
# assumptions not made explicit for power
#
# 109
# 00:04:26,330 --> 00:04:30,319
# fidelity wasn't one of the points
#
# 110
# 00:04:28,280 --> 00:04:32,810
# involved that every argument including a
#
# 111
# 00:04:30,319 --> 00:04:35,659
# mathematical proof has to have premises
#
# 112
# 00:04:32,810 --> 00:04:38,509
# and what those premises are often
#
# 113
# 00:04:35,659 --> 00:04:40,580
# creates problems and he tried to show
#
# 114
# 00:04:38,509 --> 00:04:42,919
# that all mathematics was ultimately
#
# 115
# 00:04:40,580 --> 00:04:46,550
# derived from pure principles of logic
#
# 116
# 00:04:42,919 --> 00:04:49,430
# exactly his mercy and Russell did this
#
# 117
# 00:04:46,550 --> 00:04:52,310
# and this involved to enterprise is first
#
# 118
# 00:04:49,430 --> 00:04:54,830
# of all defining mathematical concepts
#
# 119
# 00:04:52,310 --> 00:04:57,139
# enjoy logical one and secondly showing
#
# 120
# 00:04:54,830 --> 00:04:59,449
# that mathematics recently gave me how
#
# 121
# 00:04:57,139 --> 00:05:02,449
# not all mathematics but arithmetic was
#
# 122
# 00:04:59,449 --> 00:05:06,050
# reducible from Charlie logical premises
#
# 123
# 00:05:02,449 --> 00:05:08,629
# and this was achieved the first part was
#
# 124
# 00:05:06,050 --> 00:05:10,789
# a she'd fairly simply I think that it's
#
# 125
# 00:05:08,629 --> 00:05:14,469
# important station will show higher to
#
# 126
# 00:05:10,789 --> 00:05:18,560
# some if you take say a couple let's take
#
# 127
# 00:05:14,469 --> 00:05:21,080
# Tom and Jerry then you can define them
#
# 128
# 00:05:18,560 --> 00:05:23,960
# as a couple by saying that they are both
#
# 129
# 00:05:21,080 --> 00:05:25,639
# members of the set and anything which
#
# 130
# 00:05:23,960 --> 00:05:27,800
# remember was set aside is identical with
#
# 131
# 00:05:25,639 --> 00:05:30,979
# one or other of them they will define
#
# 132
# 00:05:27,800 --> 00:05:32,750
# the number two as a set of subsets for
#
# 133
# 00:05:30,979 --> 00:05:34,879
# set of couples and we do this for all
#
# 134
# 00:05:32,750 --> 00:05:37,370
# numbers more certain complications about
#
# 135
# 00:05:34,879 --> 00:05:40,159
# infinity but in this way you can define
#
# 136
# 00:05:37,370 --> 00:05:44,319
# a cardinal number in purely logical
#
# 137
# 00:05:40,159 --> 00:05:48,349
# terms what he did and then also by
#
# 138
# 00:05:44,319 --> 00:05:50,210
# generalizing logic which had until to
#
# 139
# 00:05:48,349 --> 00:05:52,729
# been done a zillion logic which had
#
# 140
# 00:05:50,210 --> 00:05:55,339
# prevailed or from ancient times until
#
# 141
# 00:05:52,729 --> 00:06:00,879
# the 19th century was not wholly general
#
# 142
# 00:05:55,339 --> 00:06:03,620
# he was able to state premises from which
#
# 143
# 00:06:00,879 --> 00:06:05,810
# most risk equals Abdullah's reducible it
#
# 144
# 00:06:03,620 --> 00:06:09,680
# was shown later by somebody about our
#
# 145
# 00:06:05,810 --> 00:06:11,180
# the logician the Austrian girdle that in
#
# 146
# 00:06:09,680 --> 00:06:13,400
# fact this couldn't be can pick you down
#
# 147
# 00:06:11,180 --> 00:06:15,650
# the diversity couldn't be completed but
#
# 148
# 00:06:13,400 --> 00:06:17,779
# the intrabody could be completed figure
#
# 149
# 00:06:15,650 --> 00:06:20,360
# a method of doing it wouldn't it also be
#
# 150
# 00:06:17,779 --> 00:06:22,190
# true to say that the full Frager of the
#
# 151
# 00:06:20,360 --> 00:06:24,289
# laws of logic had been regarded as laws
#
# 152
# 00:06:22,190 --> 00:06:27,110
# of thought that's to say of something to
#
# 153
# 00:06:24,289 --> 00:06:27,740
# do with human mental processes but
#
# 154
# 00:06:27,110 --> 00:06:30,080
# Frager
#
# 155
# 00:06:27,740 --> 00:06:32,779
# realized that that but this couldn't be
#
# 156
# 00:06:30,080 --> 00:06:35,630
# so that the validity of a proof couldn't
#
# 157
# 00:06:32,779 --> 00:06:37,310
# depend on our psychology oh yes this was
#
# 158
# 00:06:35,630 --> 00:06:39,649
# very important this is one of one of the
#
# 159
# 00:06:37,310 --> 00:06:39,980
# most important things that Sega did and
#
# 160
# 00:06:39,649 --> 00:06:42,860
# he
#
# 161
# 00:06:39,980 --> 00:06:46,160
# again by one of his early work was an
#
# 162
# 00:06:42,860 --> 00:06:48,920
# attack on a book of autistic by James
#
# 163
# 00:06:46,160 --> 00:06:51,200
# Lafleur called his cell in which logic
#
# 164
# 00:06:48,920 --> 00:06:54,110
# was represented as a theory of judgment
#
# 165
# 00:06:51,200 --> 00:06:56,930
# and this was hybrid ruled by the German
#
# 166
# 00:06:54,110 --> 00:06:58,910
# idealists and fragrance sisters it was
#
# 167
# 00:06:56,930 --> 00:07:03,380
# entirely objective and I could do it
#
# 168
# 00:06:58,910 --> 00:07:05,150
# with psychological processes but set in
#
# 169
# 00:07:03,380 --> 00:07:08,170
# Capriccio deuce numbers were entirely
#
# 170
# 00:07:05,150 --> 00:07:11,270
# objective things and that logic was
#
# 171
# 00:07:08,170 --> 00:07:13,640
# cracking dependent or of wasn't about
#
# 172
# 00:07:11,270 --> 00:07:16,700
# psychology at all these were objective
#
# 173
# 00:07:13,640 --> 00:07:18,710
# truths which of course the mind is
#
# 174
# 00:07:16,700 --> 00:07:21,320
# capable of gasping they didn't depend
#
# 175
# 00:07:18,710 --> 00:07:23,240
# upon features of thinking so the search
#
# 176
# 00:07:21,320 --> 00:07:26,120
# then becomes in a matter Batman ematic
#
# 177
# 00:07:23,240 --> 00:07:28,990
# aloof for watching tears that the proof
#
# 178
# 00:07:26,120 --> 00:07:31,280
# conveys from step to step attracts that
#
# 179
# 00:07:28,990 --> 00:07:33,470
# impersonally validates the conclusion
#
# 180
# 00:07:31,280 --> 00:07:36,530
# after regardless of how we think and
#
# 181
# 00:07:33,470 --> 00:07:39,200
# this in a way accounts for figure having
#
# 182
# 00:07:36,530 --> 00:07:40,730
# a sucessful interest beyond his 20
#
# 183
# 00:07:39,200 --> 00:07:44,210
# mathematical work but what he also
#
# 184
# 00:07:40,730 --> 00:07:47,720
# developed a theory of meaning a theory
#
# 185
# 00:07:44,210 --> 00:07:50,540
# of meaning which would show how
#
# 186
# 00:07:47,720 --> 00:07:55,090
# mathematics could be objectively valid
#
# 187
# 00:07:50,540 --> 00:07:58,610
# and he talked of the he tied up the
#
# 188
# 00:07:55,090 --> 00:08:00,020
# meaning of measure of statement but it
#
# 189
# 00:07:58,610 --> 00:08:03,770
# could be said to state was in general
#
# 190
# 00:08:00,020 --> 00:08:06,140
# with truth conditions with with the
#
# 191
# 00:08:03,770 --> 00:08:08,660
# features in them that made them
#
# 192
# 00:08:06,140 --> 00:08:10,880
# candidates for tools of office I suppose
#
# 193
# 00:08:08,660 --> 00:08:12,680
# the most historically influential
#
# 194
# 00:08:10,880 --> 00:08:14,510
# distinction that he introduced was the
#
# 195
# 00:08:12,680 --> 00:08:15,680
# distinction between sense and reference
#
# 196
# 00:08:14,510 --> 00:08:16,970
# mm-hm
#
# 197
# 00:08:15,680 --> 00:08:18,350
# which has to do with his theory of
#
# 198
# 00:08:16,970 --> 00:08:20,390
# meaning and one still has people
#
# 199
# 00:08:18,350 --> 00:08:22,610
# constantly referring to this can you
#
# 200
# 00:08:20,390 --> 00:08:24,830
# explain it yes it's it's fairly it's
#
# 201
# 00:08:22,610 --> 00:08:26,690
# fairly complicated the tool German
#
# 202
# 00:08:24,830 --> 00:08:28,970
# accessions ours in which is generally
#
# 203
# 00:08:26,690 --> 00:08:32,180
# associated sense and the duck tongue
#
# 204
# 00:08:28,970 --> 00:08:35,000
# which is translated what is it that the
#
# 205
# 00:08:32,180 --> 00:08:36,290
# German word for meaning but is bad loss
#
# 206
# 00:08:35,000 --> 00:08:40,750
# was usually translated as either
#
# 207
# 00:08:36,290 --> 00:08:44,750
# reference or unification and the
#
# 208
# 00:08:40,750 --> 00:08:47,330
# denotation of a name is the object to
#
# 209
# 00:08:44,750 --> 00:08:51,560
# which it which it names I mean
#
# 210
# 00:08:47,330 --> 00:08:53,110
# communication of Brahmaji is is you the
#
# 211
# 00:08:51,560 --> 00:08:58,160
# actual stuff
#
# 212
# 00:08:53,110 --> 00:09:02,990
# whereas the sense of them is the
#
# 213
# 00:08:58,160 --> 00:09:07,610
# contribution that it makes to the
#
# 214
# 00:09:02,990 --> 00:09:10,340
# meaning and if I just say Tom you have
#
# 215
# 00:09:07,610 --> 00:09:13,880
# say to me who's Tom and then I say well
#
# 216
# 00:09:10,340 --> 00:09:15,830
# Tom Easterners Baba and all the person
#
# 217
# 00:09:13,880 --> 00:09:17,450
# who invented such and such or all the
#
# 218
# 00:09:15,830 --> 00:09:19,670
# first person the titles of a mountain
#
# 219
# 00:09:17,450 --> 00:09:22,580
# and in this way I give you a sense and
#
# 220
# 00:09:19,670 --> 00:09:25,640
# in this way I'm able to identify him now
#
# 221
# 00:09:22,580 --> 00:09:29,000
# this distinction becomes important in
#
# 222
# 00:09:25,640 --> 00:09:31,610
# certain contexts generally what you care
#
# 223
# 00:09:29,000 --> 00:09:34,430
# about in the case of a name is what the
#
# 224
# 00:09:31,610 --> 00:09:36,920
# name stands for and but there are
#
# 225
# 00:09:34,430 --> 00:09:40,910
# certain cases where it's important to
#
# 226
# 00:09:36,920 --> 00:09:43,520
# make a distinction between sense and
#
# 227
# 00:09:40,910 --> 00:09:46,280
# unification and one good example would
#
# 228
# 00:09:43,520 --> 00:09:48,770
# be statement to identity the frege's own
#
# 229
# 00:09:46,280 --> 00:09:52,520
# a favorite example was that of the
#
# 230
# 00:09:48,770 --> 00:09:55,820
# evening star and the morning star both
#
# 231
# 00:09:52,520 --> 00:09:58,760
# of which as you know are very same stuff
#
# 232
# 00:09:55,820 --> 00:10:01,910
# they have our Venus yeah and but if
#
# 233
# 00:09:58,760 --> 00:10:05,000
# someone says leading stars identify the
#
# 234
# 00:10:01,910 --> 00:10:07,730
# morning star a man takes the reference
#
# 235
# 00:10:05,000 --> 00:10:10,310
# of these two expressions to be a lady
#
# 236
# 00:10:07,730 --> 00:10:12,290
# notation then he simply saying Venus is
#
# 237
# 00:10:10,310 --> 00:10:13,760
# Venus which is a tautology and of no
#
# 238
# 00:10:12,290 --> 00:10:15,500
# interest whereas in fact the morning
#
# 239
# 00:10:13,760 --> 00:10:18,190
# star in the unisza is a mathematical
#
# 240
# 00:10:15,500 --> 00:10:20,660
# discovery and therefore in this usage
#
# 241
# 00:10:18,190 --> 00:10:23,180
# but the excessive desert who is not
#
# 242
# 00:10:20,660 --> 00:10:26,480
# study notation not the objects but their
#
# 243
# 00:10:23,180 --> 00:10:28,880
# senses so in other words he analyzed
#
# 244
# 00:10:26,480 --> 00:10:32,720
# that may have a sense but not have a
#
# 245
# 00:10:28,880 --> 00:10:36,370
# reference yes this can happen but in Rob
#
# 246
# 00:10:32,720 --> 00:10:40,910
# in well this happens in two ways and
#
# 247
# 00:10:36,370 --> 00:10:45,470
# there could be name or nominal
#
# 248
# 00:10:40,910 --> 00:10:47,410
# expressions like here for example which
#
# 249
# 00:10:45,470 --> 00:10:51,470
# have a sense but no reference because
#
# 250
# 00:10:47,410 --> 00:10:54,130
# nobody car correspond to it and also
#
# 251
# 00:10:51,470 --> 00:10:57,710
# there is a complicated case of
#
# 252
# 00:10:54,130 --> 00:11:00,770
# expressions which have a function in in
#
# 253
# 00:10:57,710 --> 00:11:04,070
# a sentence as significant to it making
#
# 254
# 00:11:00,770 --> 00:11:05,840
# it capable of intro false
#
# 255
# 00:11:04,070 --> 00:11:07,119
# but don't you know the same like
#
# 256
# 00:11:05,840 --> 00:11:10,490
# predicate
#
# 257
# 00:11:07,119 --> 00:11:12,529
# is-is-is good is bad it's Lanza which
#
# 258
# 00:11:10,490 --> 00:11:15,740
# themselves are what he call it beat
#
# 259
# 00:11:12,529 --> 00:11:18,199
# expressions namely don't hit themselves
#
# 260
# 00:11:15,740 --> 00:11:20,930
# have a reference but contribute to
#
# 261
# 00:11:18,199 --> 00:11:22,850
# giving the sentence a sense and through
#
# 262
# 00:11:20,930 --> 00:11:25,069
# its sensor reference and these
#
# 263
# 00:11:22,850 --> 00:11:27,679
# distinctions that he introduced and his
#
# 264
# 00:11:25,069 --> 00:11:29,569
# theory of meeting had in fact had a very
#
# 265
# 00:11:27,679 --> 00:11:31,639
# widespread influence in philosophy and
#
# 266
# 00:11:29,569 --> 00:11:33,679
# they've become very fashionable in
#
# 267
# 00:11:31,639 --> 00:11:38,629
# recent years and you say and and there's
#
# 268
# 00:11:33,679 --> 00:11:41,389
# been a change in the anyhow in England
#
# 269
# 00:11:38,629 --> 00:11:44,839
# and testable in the del United States
#
# 270
# 00:11:41,389 --> 00:11:47,029
# are extended a change in the main
#
# 271
# 00:11:44,839 --> 00:11:49,279
# concern of loss it's a very long time
#
# 272
# 00:11:47,029 --> 00:11:54,499
# the theory of knowledge was dominant
#
# 273
# 00:11:49,279 --> 00:11:56,749
# ever since Descartes in the seventeenth
#
# 274
# 00:11:54,499 --> 00:11:59,420
# century the main concerns in a theory of
#
# 275
# 00:11:56,749 --> 00:12:01,790
# knowledge what be what what we can know
#
# 276
# 00:11:59,420 --> 00:12:03,920
# and how we can know how we are justified
#
# 277
# 00:12:01,790 --> 00:12:05,990
# know it in the beliefs we do and in
#
# 278
# 00:12:03,920 --> 00:12:07,990
# recent years has given way to what
#
# 279
# 00:12:05,990 --> 00:12:10,999
# sometimes called the philosophy of logic
#
# 280
# 00:12:07,990 --> 00:12:14,269
# which is mainly concerned with questions
#
# 281
# 00:12:10,999 --> 00:12:15,800
# about meaning and here sega's coming to
#
# 282
# 00:12:14,269 --> 00:12:17,899
# great prominence from Princeton's my
#
# 283
# 00:12:15,800 --> 00:12:20,959
# successors successor of logic at oxford
#
# 284
# 00:12:17,899 --> 00:12:24,350
# the macadam it has rotated nearly i mean
#
# 285
# 00:12:20,959 --> 00:12:27,019
# certainly two large books to sega's work
#
# 286
# 00:12:24,350 --> 00:12:29,300
# and is concerned exploring the
#
# 287
# 00:12:27,019 --> 00:12:30,379
# implications of frege's distinction for
#
# 288
# 00:12:29,300 --> 00:12:32,660
# a theory of meaning
#
# 289
# 00:12:30,379 --> 00:12:34,910
# so Michael Dermott who I suppose it must
#
# 290
# 00:12:32,660 --> 00:12:36,949
# be called the leading living commentator
#
# 291
# 00:12:34,910 --> 00:12:38,959
# on fragrance makes enormously large
#
# 292
# 00:12:36,949 --> 00:12:41,269
# claims for him lovely he says that he's
#
# 293
# 00:12:38,959 --> 00:12:45,019
# introduced a whole new era in philosophy
#
# 294
# 00:12:41,269 --> 00:12:47,059
# but he has D psychologize philosophy but
#
# 295
# 00:12:45,019 --> 00:12:49,549
# in the way you just explained he he
#
# 296
# 00:12:47,059 --> 00:12:51,129
# throws the theory of knowledge from the
#
# 297
# 00:12:49,549 --> 00:12:53,569
# center of the law and this has changed
#
# 298
# 00:12:51,129 --> 00:12:55,429
# 300 years of philosophical development
#
# 299
# 00:12:53,569 --> 00:12:57,529
# well I think you go along with that well
#
# 300
# 00:12:55,429 --> 00:12:59,839
# I think that there has been a different
#
# 301
# 00:12:57,529 --> 00:13:01,759
# emphasis but I think that Michael
#
# 302
# 00:12:59,839 --> 00:13:03,949
# exaggerated in two ways first of all
#
# 303
# 00:13:01,759 --> 00:13:05,720
# Russell's are always been concerned with
#
# 304
# 00:13:03,949 --> 00:13:08,720
# meaning ever since Socrates
#
# 305
# 00:13:05,720 --> 00:13:10,999
# went about saying what is knowledge what
#
# 306
# 00:13:08,720 --> 00:13:13,309
# is what is goodness and so on which is a
#
# 307
# 00:13:10,999 --> 00:13:14,779
# way of asking what what feeds about the
#
# 308
# 00:13:13,309 --> 00:13:17,730
# grease turbulence of these terms meant
#
# 309
# 00:13:14,779 --> 00:13:21,060
# was always an interest in in meaning is
#
# 310
# 00:13:17,730 --> 00:13:22,530
# in in fluffier and secondly I don't
#
# 311
# 00:13:21,060 --> 00:13:24,630
# think interest in the theory of
#
# 312
# 00:13:22,530 --> 00:13:26,970
# knowledge and certainly disappeared I
#
# 313
# 00:13:24,630 --> 00:13:29,820
# think it I think that there are some
#
# 314
# 00:13:26,970 --> 00:13:33,450
# people who are connected with with with
#
# 315
# 00:13:29,820 --> 00:13:36,630
# concern to this and insofar as even in
#
# 316
# 00:13:33,450 --> 00:13:41,040
# academics own work the area meaning is
#
# 317
# 00:13:36,630 --> 00:13:43,230
# very much bound up with questions about
#
# 318
# 00:13:41,040 --> 00:13:45,210
# truth and falsehood this also doesn't
#
# 319
# 00:13:43,230 --> 00:13:46,590
# entirely take us away from the idea of
#
# 320
# 00:13:45,210 --> 00:13:48,210
# knowledge because after all as Illinois
#
# 321
# 00:13:46,590 --> 00:13:49,830
# is concerned with what reason we have to
#
# 322
# 00:13:48,210 --> 00:13:52,260
# suppose that certain statements
#
# 323
# 00:13:49,830 --> 00:13:54,240
# propositions are true or false so I
#
# 324
# 00:13:52,260 --> 00:13:57,990
# think that they had initiative emphasis
#
# 325
# 00:13:54,240 --> 00:14:00,240
# but not the great break the damage
#
# 326
# 00:13:57,990 --> 00:14:02,130
# insist on before we continue with the
#
# 327
# 00:14:00,240 --> 00:14:04,350
# more recent applications of the frege's
#
# 328
# 00:14:02,130 --> 00:14:06,840
# work I want to turn to Russell for a
#
# 329
# 00:14:04,350 --> 00:14:08,520
# moment when I introduced this discussion
#
# 330
# 00:14:06,840 --> 00:14:10,650
# I emphasized the fact that Frager worked
#
# 331
# 00:14:08,520 --> 00:14:12,240
# in isolation throughout almost the whole
#
# 332
# 00:14:10,650 --> 00:14:14,160
# of his life and this becomes very
#
# 333
# 00:14:12,240 --> 00:14:16,560
# important when one starts to consider
#
# 334
# 00:14:14,160 --> 00:14:18,980
# Russell because for Russell spent the
#
# 335
# 00:14:16,560 --> 00:14:21,390
# first several years of his life
#
# 336
# 00:14:18,980 --> 00:14:23,280
# reinventing work that Reagan already
#
# 337
# 00:14:21,390 --> 00:14:25,770
# done without realizing he'd done it
#
# 338
# 00:14:23,280 --> 00:14:28,530
# didn't be capture that should make it
#
# 339
# 00:14:25,770 --> 00:14:29,970
# rather easy for you to explain to us
#
# 340
# 00:14:28,530 --> 00:14:32,040
# something about the importance of
#
# 341
# 00:14:29,970 --> 00:14:35,160
# Russell's very early well I don't quite
#
# 342
# 00:14:32,040 --> 00:14:37,740
# know I would say poor Russell because it
#
# 343
# 00:14:35,160 --> 00:14:41,070
# gets like true that Russell did a lot of
#
# 344
# 00:14:37,740 --> 00:14:45,180
# work that Vega had done before him but
#
# 345
# 00:14:41,070 --> 00:14:48,510
# Russell also exposed a fatal deficiency
#
# 346
# 00:14:45,180 --> 00:14:50,970
# in Vegas system he showed the Vegas
#
# 347
# 00:14:48,510 --> 00:14:52,830
# system of logic actually contained the
#
# 348
# 00:14:50,970 --> 00:14:54,810
# paradox that it knows who should respond
#
# 349
# 00:14:52,830 --> 00:14:57,090
# about addiction of a permenant he is the
#
# 350
# 00:14:54,810 --> 00:15:00,300
# question serve all people as in plumbers
#
# 351
# 00:14:57,090 --> 00:15:02,610
# and it comes into the category of
#
# 352
# 00:15:00,300 --> 00:15:04,200
# self-defeating proposition and in well
#
# 353
# 00:15:02,610 --> 00:15:06,300
# although on the surface it seems to be
#
# 354
# 00:15:04,200 --> 00:15:08,400
# trivial it's not trivial beneficial it
#
# 355
# 00:15:06,300 --> 00:15:09,780
# shows that the underlying argumentation
#
# 356
# 00:15:08,400 --> 00:15:13,470
# has something wrong with it he does it
#
# 357
# 00:15:09,780 --> 00:15:16,500
# shows one of one of Sega's essential
#
# 358
# 00:15:13,470 --> 00:15:18,870
# assumptions lead contradiction and when
#
# 359
# 00:15:16,500 --> 00:15:21,930
# and Russell in nineteen that he wasn't
#
# 360
# 00:15:18,870 --> 00:15:24,780
# making three conveyed this in a letter
#
# 361
# 00:15:21,930 --> 00:15:27,120
# to Frager and Sega's first reaction was
#
# 362
# 00:15:24,780 --> 00:15:28,980
# not oh I'm wrong you've seen the
#
# 363
# 00:15:27,120 --> 00:15:31,250
# arrogance reply the whole of mathematics
#
# 364
# 00:15:28,980 --> 00:15:35,010
# has been shown to be worthless
#
# 365
# 00:15:31,250 --> 00:15:40,680
# eddie thawne is going too far and he
#
# 366
# 00:15:35,010 --> 00:15:43,950
# then managed to put together some sort
#
# 367
# 00:15:40,680 --> 00:15:46,260
# of answer to Russell's addiction but
#
# 368
# 00:15:43,950 --> 00:15:49,290
# then it was shown earlier figures death
#
# 369
# 00:15:46,260 --> 00:15:52,320
# exact by a Paris edition that figures
#
# 370
# 00:15:49,290 --> 00:15:54,630
# answer also option
#
# 371
# 00:15:52,320 --> 00:15:58,100
# Otto Bishop to think of the Bishop see
#
# 372
# 00:15:54,630 --> 00:16:00,600
# yes we know really good news at buttons
#
# 373
# 00:15:58,100 --> 00:16:03,120
# you learn self said earlier you never
#
# 374
# 00:16:00,600 --> 00:16:05,310
# wrote the third volume and he simply
#
# 375
# 00:16:03,120 --> 00:16:06,930
# came up from 19 three to nineteen twenty
#
# 376
# 00:16:05,310 --> 00:16:08,160
# five is getting evidently and this was
#
# 377
# 00:16:06,930 --> 00:16:10,380
# the result he thought his life's work
#
# 378
# 00:16:08,160 --> 00:16:14,850
# and his life had been demolished yes yes
#
# 379
# 00:16:10,380 --> 00:16:17,670
# so that in fact it was very sad story
#
# 380
# 00:16:14,850 --> 00:16:19,980
# yeah can his only it remains true I had
#
# 381
# 00:16:17,670 --> 00:16:22,560
# oughta press this point but an enormous
#
# 382
# 00:16:19,980 --> 00:16:24,899
# amount of the work that Russell had done
#
# 383
# 00:16:22,560 --> 00:16:27,420
# and spent years over fraida had already
#
# 384
# 00:16:24,899 --> 00:16:29,730
# died and Russell didn't know that issue
#
# 385
# 00:16:27,420 --> 00:16:32,339
# but it's also true but although favor
#
# 386
# 00:16:29,730 --> 00:16:33,779
# did its first and some experts today
#
# 387
# 00:16:32,339 --> 00:16:36,420
# think that they did did most of it
#
# 388
# 00:16:33,779 --> 00:16:38,370
# better it was through Russell that the
#
# 389
# 00:16:36,420 --> 00:16:40,050
# ideas actually became famous in
#
# 390
# 00:16:38,370 --> 00:16:42,540
# philosophy and influential in philosophy
#
# 391
# 00:16:40,050 --> 00:16:45,990
# that is true I don't know why it was the
#
# 392
# 00:16:42,540 --> 00:16:51,089
# figures work was so neglected a park
#
# 393
# 00:16:45,990 --> 00:16:53,520
# across from third reason that interest
#
# 394
# 00:16:51,089 --> 00:16:55,079
# in new developments of logic was very
#
# 395
# 00:16:53,520 --> 00:16:58,160
# much in English seeing people like who
#
# 396
# 00:16:55,079 --> 00:17:01,170
# the Morgan wasn't taken up in Germany
#
# 397
# 00:16:58,160 --> 00:17:02,970
# because in Germany the psychological
#
# 398
# 00:17:01,170 --> 00:17:05,250
# mistaken psychological view of logic
#
# 399
# 00:17:02,970 --> 00:17:06,839
# still prevailed and wasn't taken up in
#
# 400
# 00:17:05,250 --> 00:17:09,990
# England dicta because of English in
#
# 401
# 00:17:06,839 --> 00:17:12,449
# severity and in incompetence and foreign
#
# 402
# 00:17:09,990 --> 00:17:14,100
# languages and wallet levered Russell
#
# 403
# 00:17:12,449 --> 00:17:16,500
# have been brought up by German gut
#
# 404
# 00:17:14,100 --> 00:17:18,420
# missus in German nurses did know German
#
# 405
# 00:17:16,500 --> 00:17:19,650
# but even roughly but indirectly what
#
# 406
# 00:17:18,420 --> 00:17:21,390
# happened was the Russell and
#
# 407
# 00:17:19,650 --> 00:17:24,030
# collaborator white-haired went to a
#
# 408
# 00:17:21,390 --> 00:17:28,170
# Congress in Paris in nineteen three I
#
# 409
# 00:17:24,030 --> 00:17:31,020
# met Natalia logician called piano and it
#
# 410
# 00:17:28,170 --> 00:17:33,030
# was super on Oh who's working normally
#
# 411
# 00:17:31,020 --> 00:17:34,380
# best them and who was working in the
#
# 412
# 00:17:33,030 --> 00:17:37,170
# same direction though we were less
#
# 413
# 00:17:34,380 --> 00:17:39,030
# efficient at the science of logic which
#
# 414
# 00:17:37,170 --> 00:17:42,090
# had remained virtually static for over
#
# 415
# 00:17:39,030 --> 00:17:44,810
# 2,000 years since Aristotle suddenly
#
# 416
# 00:17:42,090 --> 00:17:47,000
# exploded their whole new
#
# 417
# 00:17:44,810 --> 00:17:49,220
# and in normal you know I feel so rough
#
# 418
# 00:17:47,000 --> 00:17:51,200
# mein little Russell and we're kids
#
# 419
# 00:17:49,220 --> 00:17:54,410
# Principia Mathematica which she took
#
# 420
# 00:17:51,200 --> 00:17:55,910
# them together about ten jenny zurawell
#
# 421
# 00:17:54,410 --> 00:17:58,430
# Russell wrote the principles of
#
# 422
# 00:17:55,910 --> 00:18:00,320
# mathematics in nineteen three where he
#
# 423
# 00:17:58,430 --> 00:18:02,630
# does Ricky Martin went to Prague I think
#
# 424
# 00:18:00,320 --> 00:18:04,880
# in the preparation and India periods
#
# 425
# 00:18:02,630 --> 00:18:08,150
# yes and then then he went on with his
#
# 426
# 00:18:04,880 --> 00:18:10,550
# Vidya tutor at twenty Cambridge
#
# 427
# 00:18:08,150 --> 00:18:12,890
# Whitehead to write a free volume work
#
# 428
# 00:18:10,550 --> 00:18:15,710
# called Panchita Mathematica in which he
#
# 429
# 00:18:12,890 --> 00:18:18,110
# actually tried to do the work of
#
# 430
# 00:18:15,710 --> 00:18:21,680
# reducing mathematics from logic and it's
#
# 431
# 00:18:18,110 --> 00:18:23,930
# full of formulae and because it gives a
#
# 432
# 00:18:21,680 --> 00:18:26,960
# stupendous work although as you rightly
#
# 433
# 00:18:23,930 --> 00:18:28,820
# said it doesn't quite achieve the
#
# 434
# 00:18:26,960 --> 00:18:31,070
# standards about the rigor that the fair
#
# 435
# 00:18:28,820 --> 00:18:33,080
# girl achieved before it but this was the
#
# 436
# 00:18:31,070 --> 00:18:34,460
# one that really popular rides or
#
# 437
# 00:18:33,080 --> 00:18:36,530
# subjects then all sorts of people took
#
# 438
# 00:18:34,460 --> 00:18:39,080
# it out but it man it took four men on it
#
# 439
# 00:18:36,530 --> 00:18:41,090
# has proceeded by leaps and bounds and
#
# 440
# 00:18:39,080 --> 00:18:42,500
# it's now so to speak a major field of
#
# 441
# 00:18:41,090 --> 00:18:44,420
# intellectual endeavor throughout the
#
# 442
# 00:18:42,500 --> 00:18:46,070
# Mayan world in every universe but is
#
# 443
# 00:18:44,420 --> 00:18:48,770
# interesting I think also should be
#
# 444
# 00:18:46,070 --> 00:18:52,490
# mentioned that one of the effects has
#
# 445
# 00:18:48,770 --> 00:18:54,320
# been not so much to subdue mathematics
#
# 446
# 00:18:52,490 --> 00:18:56,480
# or logic which is what Sega and Russell
#
# 447
# 00:18:54,320 --> 00:19:00,110
# wanted but subdued oddity mathematics
#
# 448
# 00:18:56,480 --> 00:19:02,330
# and the in recent years seem
#
# 449
# 00:19:00,110 --> 00:19:05,150
# mathematical logic has become more and
#
# 450
# 00:19:02,330 --> 00:19:08,240
# more mathematical and less and has had
#
# 451
# 00:19:05,150 --> 00:19:11,560
# less less to do with fluffy in general
#
# 452
# 00:19:08,240 --> 00:19:14,240
# and even a disciple of figure like
#
# 453
# 00:19:11,560 --> 00:19:16,190
# Michel damage is more interested in the
#
# 454
# 00:19:14,240 --> 00:19:17,900
# semantic side of it the theory of
#
# 455
# 00:19:16,190 --> 00:19:19,670
# meaning that he had hitherto said
#
# 456
# 00:19:17,900 --> 00:19:22,100
# himself to be in the column as radical
#
# 457
# 00:19:19,670 --> 00:19:24,050
# side but unlike Frager Russell actually
#
# 458
# 00:19:22,100 --> 00:19:26,030
# made the explicit step after we've done
#
# 459
# 00:19:24,050 --> 00:19:28,550
# all this work to general philosophy
#
# 460
# 00:19:26,030 --> 00:19:30,620
# early not until he was 40 years old but
#
# 461
# 00:19:28,550 --> 00:19:33,410
# then he did and he started producing
#
# 462
# 00:19:30,620 --> 00:19:36,380
# general works of philosophy can you give
#
# 463
# 00:19:33,410 --> 00:19:38,840
# us some indication of what position well
#
# 464
# 00:19:36,380 --> 00:19:44,420
# it's very odd how little two are
#
# 465
# 00:19:38,840 --> 00:19:46,040
# connected they one place where as they
#
# 466
# 00:19:44,420 --> 00:19:49,820
# are connected is something a buffer
#
# 467
# 00:19:46,040 --> 00:19:53,960
# called the theory of descriptions there
#
# 468
# 00:19:49,820 --> 00:19:56,810
# was a puzzle about the meaning of our
#
# 469
# 00:19:53,960 --> 00:19:58,700
# statements like the present King of
#
# 470
# 00:19:56,810 --> 00:19:59,900
# France which didn't know
#
# 471
# 00:19:58,700 --> 00:20:01,820
# what did you say the president king of
#
# 472
# 00:19:59,900 --> 00:20:04,190
# France is bald yet there isn't anything
#
# 473
# 00:20:01,820 --> 00:20:05,120
# up front I never and didn't know
#
# 474
# 00:20:04,190 --> 00:20:07,670
# anything and therefore there was a
#
# 475
# 00:20:05,120 --> 00:20:09,890
# question hi could be meaningful and they
#
# 476
# 00:20:07,670 --> 00:20:12,970
# had been philosophers a medical example
#
# 477
# 00:20:09,890 --> 00:20:16,130
# is a German called my nan who then
#
# 478
# 00:20:12,970 --> 00:20:18,380
# thought of that these things no he what
#
# 479
# 00:20:16,130 --> 00:20:22,220
# he called subsystem entities and Russell
#
# 480
# 00:20:18,380 --> 00:20:24,470
# forces rubbish and he shared a way of
#
# 481
# 00:20:22,220 --> 00:20:27,950
# translating out such expressions by
#
# 482
# 00:20:24,470 --> 00:20:32,150
# saying that say in fact contained cavett
#
# 483
# 00:20:27,950 --> 00:20:35,990
# existence claims and causes in board saw
#
# 484
# 00:20:32,150 --> 00:20:38,090
# same into there is one thing that now
#
# 485
# 00:20:35,990 --> 00:20:39,470
# rules over France and whatever it is
#
# 486
# 00:20:38,090 --> 00:20:43,130
# over France is bald
#
# 487
# 00:20:39,470 --> 00:20:45,680
# okay and this got rid of the of the
#
# 488
# 00:20:43,130 --> 00:20:48,860
# apparent paradox and so in that way is
#
# 489
# 00:20:45,680 --> 00:20:51,020
# not for work edifice or implication but
#
# 490
# 00:20:48,860 --> 00:20:53,930
# in the main he simply went off from
#
# 491
# 00:20:51,020 --> 00:20:57,560
# mallet axe he says surely philosophical
#
# 492
# 00:20:53,930 --> 00:20:59,450
# book came out 1912 it's called the
#
# 493
# 00:20:57,560 --> 00:21:02,480
# problems of loss racial home university
#
# 494
# 00:20:59,450 --> 00:21:04,070
# library book and in my view still the
#
# 495
# 00:21:02,480 --> 00:21:05,900
# best introductions of losses there is
#
# 496
# 00:21:04,070 --> 00:21:07,700
# because ruffles a marvelous writer
#
# 497
# 00:21:05,900 --> 00:21:10,400
# though it's a good old-fashioned and
#
# 498
# 00:21:07,700 --> 00:21:13,070
# there he really takes no account he's
#
# 499
# 00:21:10,400 --> 00:21:14,930
# also look at all he simply continues the
#
# 500
# 00:21:13,070 --> 00:21:16,750
# British imperialist edition this is a
#
# 501
# 00:21:14,930 --> 00:21:19,670
# book and follows straight on from
#
# 502
# 00:21:16,750 --> 00:21:21,290
# Berkeley Locke park in Hume and it
#
# 503
# 00:21:19,670 --> 00:21:23,840
# starts off with the failure of
#
# 504
# 00:21:21,290 --> 00:21:25,250
# perceptions they like Berkeley there it
#
# 505
# 00:21:23,840 --> 00:21:27,560
# says that what we perceive and not
#
# 506
# 00:21:25,250 --> 00:21:29,690
# stables and jazz and things but what
#
# 507
# 00:21:27,560 --> 00:21:32,810
# barking but Locke called simple ideas
#
# 508
# 00:21:29,690 --> 00:21:36,260
# what Russell following his friend work
#
# 509
# 00:21:32,810 --> 00:21:39,080
# or sin theta and then another recent
#
# 510
# 00:21:36,260 --> 00:21:41,330
# audience awful question how on the basis
#
# 511
# 00:21:39,080 --> 00:21:43,100
# of being presented with the st.
#
# 512
# 00:21:41,330 --> 00:21:45,260
# impressions we arrive at physical
#
# 513
# 00:21:43,100 --> 00:21:48,170
# objects so then he deals is the sense
#
# 514
# 00:21:45,260 --> 00:21:53,540
# additional to suffer problems in in that
#
# 515
# 00:21:48,170 --> 00:21:55,420
# sort of way and he more or less gave up
#
# 516
# 00:21:53,540 --> 00:21:59,080
# logic after
#
# 517
# 00:21:55,420 --> 00:22:04,190
# consumed animatic ieave self said that
#
# 518
# 00:21:59,080 --> 00:22:06,200
# this wore him out he collaborated in the
#
# 519
# 00:22:04,190 --> 00:22:08,120
# books on a book with Whitehead but
#
# 520
# 00:22:06,200 --> 00:22:11,090
# Whitehead was teaching mathematics at
#
# 521
# 00:22:08,120 --> 00:22:12,530
# Cambridge and mainly occupied was that
#
# 522
# 00:22:11,090 --> 00:22:14,750
# Russell that
#
# 523
# 00:22:12,530 --> 00:22:16,490
# was living independently already had a
#
# 524
# 00:22:14,750 --> 00:22:18,740
# lectureship at a mixer and I could get
#
# 525
# 00:22:16,490 --> 00:22:20,540
# that 15 but in the first decade of the
#
# 526
# 00:22:18,740 --> 00:22:23,690
# century he was living on his independent
#
# 527
# 00:22:20,540 --> 00:22:26,000
# income and so he had @y actual worker
#
# 528
# 00:22:23,690 --> 00:22:30,020
# back at all his proofs and he shared
#
# 529
# 00:22:26,000 --> 00:22:31,850
# that this really fascinated him ever
#
# 530
# 00:22:30,020 --> 00:22:35,090
# doing any detailed work in future and
#
# 531
# 00:22:31,850 --> 00:22:37,850
# some extent true all his later work is
#
# 532
# 00:22:35,090 --> 00:22:40,130
# full of brilliant ideas he never he no
#
# 533
# 00:22:37,850 --> 00:22:41,510
# fully works out it doesn't get bored
#
# 534
# 00:22:40,130 --> 00:22:43,850
# he's obviously it goes on like this oh
#
# 535
# 00:22:41,510 --> 00:22:47,360
# he doesn't bother to dot the i's and
#
# 536
# 00:22:43,850 --> 00:22:49,880
# cross the two awards go to work I think
#
# 537
# 00:22:47,360 --> 00:22:51,380
# that I see one very important continuing
#
# 538
# 00:22:49,880 --> 00:22:52,730
# concern in the later work I've been
#
# 539
# 00:22:51,380 --> 00:22:55,130
# should know if you agree with this or
#
# 540
# 00:22:52,730 --> 00:22:57,110
# not you've just said I'm sure rightly
#
# 541
# 00:22:55,130 --> 00:22:58,790
# that that Russell was a radical
#
# 542
# 00:22:57,110 --> 00:23:01,700
# empiricist you know a direct tradition
#
# 543
# 00:22:58,790 --> 00:23:03,650
# of Locke and humanly it seems to me the
#
# 544
# 00:23:01,700 --> 00:23:07,190
# Brussels was always concerned to
#
# 545
# 00:23:03,650 --> 00:23:10,100
# validate the Natural Sciences in terms
#
# 546
# 00:23:07,190 --> 00:23:11,870
# of sense data that he always wanted to
#
# 547
# 00:23:10,100 --> 00:23:14,060
# show that the whole corpus of our
#
# 548
# 00:23:11,870 --> 00:23:16,850
# scientific knowledge could be derived
#
# 549
# 00:23:14,060 --> 00:23:19,250
# from and was derived from nothing but
#
# 550
# 00:23:16,850 --> 00:23:22,040
# observations and our reflections on our
#
# 551
# 00:23:19,250 --> 00:23:24,530
# object well not always
#
# 552
# 00:23:22,040 --> 00:23:26,810
# I think you'll make one very important
#
# 553
# 00:23:24,530 --> 00:23:29,900
# to important point here and well in fact
#
# 554
# 00:23:26,810 --> 00:23:31,490
# that I overlooked when I was talking a
#
# 555
# 00:23:29,900 --> 00:23:34,580
# few moments ago and that is that from
#
# 556
# 00:23:31,490 --> 00:23:36,740
# the very beginning Russell's approaches
#
# 557
# 00:23:34,580 --> 00:23:39,260
# philosophy was an interesting
#
# 558
# 00:23:36,740 --> 00:23:42,020
# justification of reading using story
#
# 559
# 00:23:39,260 --> 00:23:44,120
# that when use about 12 his older brother
#
# 560
# 00:23:42,020 --> 00:23:45,980
# who was said to school Russell to store
#
# 561
# 00:23:44,120 --> 00:23:49,000
# at home the other brother Franco said
#
# 562
# 00:23:45,980 --> 00:23:51,740
# school taught Russell geometry and
#
# 563
# 00:23:49,000 --> 00:23:53,720
# Russell refused to accept the actions he
#
# 564
# 00:23:51,740 --> 00:23:56,420
# wanted to have improved and mibella said
#
# 565
# 00:23:53,720 --> 00:23:58,010
# that they couldn't get on mystic you got
#
# 566
# 00:23:56,420 --> 00:24:01,370
# to exhibit the actions they agreed to
#
# 567
# 00:23:58,010 --> 00:24:03,470
# originally but he always wanted to have
#
# 568
# 00:24:01,370 --> 00:24:05,300
# everything justified and this was common
#
# 569
# 00:24:03,470 --> 00:24:07,400
# both in his approach to logical
#
# 570
# 00:24:05,300 --> 00:24:09,290
# mathematics and his approach to other
#
# 571
# 00:24:07,400 --> 00:24:11,420
# branches of knowledge and as you say
#
# 572
# 00:24:09,290 --> 00:24:14,390
# also means opposed to science he wanted
#
# 573
# 00:24:11,420 --> 00:24:19,570
# to have a spacious flower buddy concerns
#
# 574
# 00:24:14,390 --> 00:24:23,450
# and but here he is used buried in the
#
# 575
# 00:24:19,570 --> 00:24:25,460
# book I mentioned a problem with
#
# 576
# 00:24:23,450 --> 00:24:26,240
# philosophy it's quite rude he won't
#
# 577
# 00:24:25,460 --> 00:24:28,550
# start
#
# 578
# 00:24:26,240 --> 00:24:30,440
# sense-data but he didn't think that all
#
# 579
# 00:24:28,550 --> 00:24:32,600
# scientific or even nor a common-sense
#
# 580
# 00:24:30,440 --> 00:24:34,640
# statement save as I had a disabled can
#
# 581
# 00:24:32,600 --> 00:24:38,060
# be could be reduced to sensory statement
#
# 582
# 00:24:34,640 --> 00:24:41,300
# he adopted a causal theory that you
#
# 583
# 00:24:38,060 --> 00:24:43,730
# could assume the existence of physical
#
# 584
# 00:24:41,300 --> 00:24:46,880
# world as the best explanation for our
#
# 585
# 00:24:43,730 --> 00:24:49,610
# sensory experiences then he changed his
#
# 586
# 00:24:46,880 --> 00:24:51,770
# view and in the next important book that
#
# 587
# 00:24:49,610 --> 00:24:54,470
# he published on theory of knowledge
#
# 588
# 00:24:51,770 --> 00:24:58,700
# which was a larger the external world
#
# 589
# 00:24:54,470 --> 00:25:01,550
# which came out in 1914 he did take the
#
# 590
# 00:24:58,700 --> 00:25:03,080
# view you just you just referred to
#
# 591
# 00:25:01,550 --> 00:25:06,320
# namely he thought you could actually
#
# 592
# 00:25:03,080 --> 00:25:08,300
# reduce every mother and every common
#
# 593
# 00:25:06,320 --> 00:25:10,790
# sense statement very scientific
#
# 594
# 00:25:08,300 --> 00:25:14,330
# statement to statements about our actual
#
# 595
# 00:25:10,790 --> 00:25:16,400
# and had possible hypothetical assent
#
# 596
# 00:25:14,330 --> 00:25:19,160
# experiences and this year is this food
#
# 597
# 00:25:16,400 --> 00:25:22,210
# this view which is technically known as
#
# 598
# 00:25:19,160 --> 00:25:25,390
# phenomenal is really most view of of
#
# 599
# 00:25:22,210 --> 00:25:27,640
# Berkeley if you rob Berkeley of God and
#
# 600
# 00:25:25,390 --> 00:25:29,720
# also the viewer John Stuart Mill was
#
# 601
# 00:25:27,640 --> 00:25:34,210
# instead the wrath of God father
#
# 602
# 00:25:29,720 --> 00:25:36,500
# may God solid oxide because unbeliever
#
# 603
# 00:25:34,210 --> 00:25:40,250
# article to believe in garbage hey
#
# 604
# 00:25:36,500 --> 00:25:43,070
# Godfather this phenomena listing you who
#
# 605
# 00:25:40,250 --> 00:25:44,960
# was developed in another external world
#
# 606
# 00:25:43,070 --> 00:25:48,590
# and also in some important essay to
#
# 607
# 00:25:44,960 --> 00:25:50,030
# Russell wrote in book cornices and logic
#
# 608
# 00:25:48,590 --> 00:25:52,820
# which he produced in the First World War
#
# 609
# 00:25:50,030 --> 00:25:54,650
# and then I say called something like
#
# 610
# 00:25:52,820 --> 00:25:58,180
# sense data and physics is the most
#
# 611
# 00:25:54,650 --> 00:26:01,220
# important lambda and he continued this
#
# 612
# 00:25:58,180 --> 00:26:03,770
# in another important book called
#
# 613
# 00:26:01,220 --> 00:26:07,400
# analysis of mind which came out I think
#
# 614
# 00:26:03,770 --> 00:26:09,260
# in 1921 and he adopted a theory which
#
# 615
# 00:26:07,400 --> 00:26:12,670
# had been advanced before him by the
#
# 616
# 00:26:09,260 --> 00:26:16,130
# pragmatist William James Henry James's
#
# 617
# 00:26:12,670 --> 00:26:19,070
# elder brother in which both mind and
#
# 618
# 00:26:16,130 --> 00:26:21,920
# matter were composed of what James
#
# 619
# 00:26:19,070 --> 00:26:25,100
# called neutral stuff and which were
#
# 620
# 00:26:21,920 --> 00:26:27,470
# wearing fact since data and images and
#
# 621
# 00:26:25,100 --> 00:26:29,000
# then they differed only in being
#
# 622
# 00:26:27,470 --> 00:26:31,580
# different arrangements with fundamental
#
# 623
# 00:26:29,000 --> 00:26:35,390
# data but then Russell gave this up and
#
# 624
# 00:26:31,580 --> 00:26:38,540
# in 925 will emphasize the curious forged
#
# 625
# 00:26:35,390 --> 00:26:39,340
# as no matter where he where that places
#
# 626
# 00:26:38,540 --> 00:26:41,200
# issues too
#
# 627
# 00:26:39,340 --> 00:26:44,350
# remaining but he mainly went back to the
#
# 628
# 00:26:41,200 --> 00:26:48,190
# causal theory that that he'd held in
#
# 629
# 00:26:44,350 --> 00:26:52,240
# 1912 and when he revived his interested
#
# 630
# 00:26:48,190 --> 00:26:56,400
# philosophy in the 1940s and any final
#
# 631
# 00:26:52,240 --> 00:26:59,560
# through all his next last Rosasco book
#
# 632
# 00:26:56,400 --> 00:27:01,480
# human largest open limits he goes back
#
# 633
# 00:26:59,560 --> 00:27:03,420
# to a causal theory he always he always
#
# 634
# 00:27:01,480 --> 00:27:09,790
# thought that the basis of our knowledge
#
# 635
# 00:27:03,420 --> 00:27:16,150
# was laying in sense variance but he
#
# 636
# 00:27:09,790 --> 00:27:17,920
# varied in in the next step I mean it was
#
# 637
# 00:27:16,150 --> 00:27:19,710
# only during one period of his work that
#
# 638
# 00:27:17,920 --> 00:27:24,700
# he thought that the whole thing could be
#
# 639
# 00:27:19,710 --> 00:27:26,290
# reduced to centric term more often and
#
# 640
# 00:27:24,700 --> 00:27:28,630
# certainly in a lot of the enemies like
#
# 641
# 00:27:26,290 --> 00:27:31,060
# very violently he he had he had the
#
# 642
# 00:27:28,630 --> 00:27:35,020
# causal theory which put the physical
#
# 643
# 00:27:31,060 --> 00:27:36,730
# world beyond the veil observation in
#
# 644
# 00:27:35,020 --> 00:27:39,090
# fact he ended up with very curious what
#
# 645
# 00:27:36,730 --> 00:27:42,310
# is the attempt to bring a wholly new
#
# 646
# 00:27:39,090 --> 00:27:44,650
# rigor to bear he'll also say not only of
#
# 647
# 00:27:42,310 --> 00:27:47,320
# a logical kind but once tempted to say
#
# 648
# 00:27:44,650 --> 00:27:49,630
# the scientific kind he was always very
#
# 649
# 00:27:47,320 --> 00:27:52,030
# concerned for example that our beliefs
#
# 650
# 00:27:49,630 --> 00:27:54,100
# should relate to the evidence form which
#
# 651
# 00:27:52,030 --> 00:27:55,990
# is something he reiterated over and over
#
# 652
# 00:27:54,100 --> 00:27:58,870
# again isn't it and it's something which
#
# 653
# 00:27:55,990 --> 00:28:01,120
# if taken seriously sweeps aside a great
#
# 654
# 00:27:58,870 --> 00:28:03,100
# deal of traditional philosophizing and
#
# 655
# 00:28:01,120 --> 00:28:05,530
# traditional thinking oh yes that let any
#
# 656
# 00:28:03,100 --> 00:28:09,730
# is true and I think that this you
#
# 657
# 00:28:05,530 --> 00:28:11,710
# already mentioned that Russell and in
#
# 658
# 00:28:09,730 --> 00:28:18,340
# from Vicki Stein indeed the concern was
#
# 659
# 00:28:11,710 --> 00:28:21,280
# Russell's bookable and as you know
#
# 660
# 00:28:18,340 --> 00:28:23,070
# Wickham Stein and also that goof losses
#
# 661
# 00:28:21,280 --> 00:28:25,240
# in Vienna called the Vienna circle
#
# 662
# 00:28:23,070 --> 00:28:28,230
# condemned what they call better physics
#
# 663
# 00:28:25,240 --> 00:28:30,940
# and metaphysics in their view was
#
# 664
# 00:28:28,230 --> 00:28:33,490
# participative least partly any attempt
#
# 665
# 00:28:30,940 --> 00:28:35,620
# ...
#
# 762
# 00:32:37,660 --> 00:32:41,230
# the fly the way out of a fire bottle to
#
# 763
# 00:32:39,400 --> 00:32:43,450
# kill people of these models well as also
#
# 764
# 00:32:41,230 --> 00:32:45,130
# always thought that philosophical
#
# 765
# 00:32:43,450 --> 00:32:48,520
# problems had a solution
#
# 766
# 00:32:45,130 --> 00:32:51,040
# and that was why he was so exposed to
#
# 767
# 00:32:48,520 --> 00:32:53,500
# the purely linguistic philosophy of our
#
# 768
# 00:32:51,040 --> 00:32:57,520
# production after war and the leadership
#
# 769
# 00:32:53,500 --> 00:33:00,340
# of us in burritos the mere explanation
#
# 770
# 00:32:57,520 --> 00:33:02,410
# of language which then sake really the
#
# 771
# 00:33:00,340 --> 00:33:06,160
# exploration of the implications of
#
# 772
# 00:33:02,410 --> 00:33:07,300
# English usage was trivial and Russell
#
# 773
# 00:33:06,160 --> 00:33:10,410
# really thought of there were questions
#
# 774
# 00:33:07,300 --> 00:33:13,390
# about justification of our beliefs that
#
# 775
# 00:33:10,410 --> 00:33:15,790
# it was business losses to answer and
#
# 776
# 00:33:13,390 --> 00:33:17,320
# these questions were answerable he
#
# 777
# 00:33:15,790 --> 00:33:19,030
# thought that the answers could be
#
# 778
# 00:33:17,320 --> 00:33:20,080
# discovered if you were to get all about
#
# 779
# 00:33:19,030 --> 00:33:22,240
# alibi didn't
#
# 780
# 00:33:20,080 --> 00:33:23,530
# we're doing I thought yet I do yes I
#
# 781
# 00:33:22,240 --> 00:33:25,630
# could say I want to put a personal
#
# 782
# 00:33:23,530 --> 00:33:27,430
# question - because you own your life you
#
# 783
# 00:33:25,630 --> 00:33:29,530
# have acknowledged that you yourself have
#
# 784
# 00:33:27,430 --> 00:33:32,740
# been enormous um so it laughs Solomon
#
# 785
# 00:33:29,530 --> 00:33:34,900
# reverence yes it always have so you can
#
# 786
# 00:33:32,740 --> 00:33:36,790
# tell us what it's like from the inside
#
# 787
# 00:33:34,900 --> 00:33:37,780
# as it were to have been influenced by
#
# 788
# 00:33:36,790 --> 00:33:39,910
# Russell
#
# 789
# 00:33:37,780 --> 00:33:43,810
# what is his influence being on you on me
#
# 790
# 00:33:39,910 --> 00:33:46,870
# uh it's been first of all but unlike
#
# 791
# 00:33:43,810 --> 00:33:49,000
# most of my contemporaries I still think
#
# 792
# 00:33:46,870 --> 00:33:51,970
# I should start with what Russell called
#
# 793
# 00:33:49,000 --> 00:33:54,340
# sense data what I not read call since
#
# 794
# 00:33:51,970 --> 00:33:59,560
# qualia that is a technical difference
#
# 795
# 00:33:54,340 --> 00:34:03,370
# whether you begin with particulars or or
#
# 796
# 00:33:59,560 --> 00:34:05,830
# something more general but he says that
#
# 797
# 00:34:03,370 --> 00:34:10,929
# example same thing so that on the whole
#
# 798
# 00:34:05,830 --> 00:34:13,900
# I share his some certainly the starting
#
# 799
# 00:34:10,929 --> 00:34:15,880
# point which is on perception I share him
#
# 800
# 00:34:13,900 --> 00:34:16,570
# I also agree with the importance of
#
# 801
# 00:34:15,880 --> 00:34:19,920
# primacy
#
# 802
# 00:34:16,570 --> 00:34:23,320
# he attaches to the theory of knowledge I
#
# 803
# 00:34:19,920 --> 00:34:26,620
# am and the law I've always been a
#
# 804
# 00:34:23,320 --> 00:34:29,140
# thoroughgoing empiricist I agree with
#
# 805
# 00:34:26,620 --> 00:34:31,870
# the view of the Russell derived from
#
# 806
# 00:34:29,140 --> 00:34:34,390
# human own a safety of a magical
#
# 807
# 00:34:31,870 --> 00:34:37,020
# sensitive so that the such a thing as
#
# 808
# 00:34:34,390 --> 00:34:40,960
# cause of this because well just remember
#
# 809
# 00:34:37,020 --> 00:34:42,940
# what Hume originally said it was namely
#
# 810
# 00:34:40,960 --> 00:34:45,669
# constant conjunction and something
#
# 811
# 00:34:42,940 --> 00:34:48,400
# purely contingent I agree with Russell
#
# 812
# 00:34:45,669 --> 00:34:50,440
# in rejecting any form of theology or any
#
# 813
# 00:34:48,400 --> 00:34:51,940
# how transcendent theology injecting
#
# 814
# 00:34:50,440 --> 00:34:55,120
# metaphysics right also most importantly
#
# 815
# 00:34:51,940 --> 00:34:57,310
# a view is Russell the frost wouldn't be
#
# 816
# 00:34:55,120 --> 00:34:59,410
# worth doing unless you'd pose questions
#
# 817
# 00:34:57,310 --> 00:35:02,200
# which we could find the answers that's
#
# 818
# 00:34:59,410 --> 00:35:04,390
# not he bets that I took camera persons
#
# 819
# 00:35:02,200 --> 00:35:06,070
# but I will eventually idea and all these
#
# 820
# 00:35:04,390 --> 00:35:08,110
# are examples not just to be or degree in
#
# 821
# 00:35:06,070 --> 00:35:10,240
# with him but at him having influence oh
#
# 822
# 00:35:08,110 --> 00:35:12,100
# yes are they all of them quickly yes
#
# 823
# 00:35:10,240 --> 00:35:13,600
# guys directly exactly and I think the
#
# 824
# 00:35:12,100 --> 00:35:15,460
# reason been to inspire him in the way
#
# 825
# 00:35:13,600 --> 00:35:17,290
# you bite haven't with that well I you
#
# 826
# 00:35:15,460 --> 00:35:19,510
# regard him as a mastering each pillars
#
# 827
# 00:35:17,290 --> 00:35:20,920
# and well I think I'm not in the same
#
# 828
# 00:35:19,510 --> 00:35:23,890
# class as Russell's Lhasa
#
# 829
# 00:35:20,920 --> 00:35:25,810
# but I do think that I do write English
#
# 830
# 00:35:23,890 --> 00:35:27,550
# reasonably well and I do get again
#
# 831
# 00:35:25,810 --> 00:35:29,230
# partly under his influence and in-game
#
# 832
# 00:35:27,550 --> 00:35:33,450
# question yes I think that was
#
# 833
# 00:35:29,230 --> 00:35:37,920
# affiliation both of ideas and style
#
# 834
# 00:35:33,450 --> 00:35:41,609
# from Hume through mill to Russell and
#
# 835
# 00:35:37,920 --> 00:35:43,980
# coming down and said to me now the
#
# 836
# 00:35:41,609 --> 00:35:46,530
# philosophers will be discussing it here
#
# 837
# 00:35:43,980 --> 00:35:48,420
# Trager and Russell had enormous effect
#
# 838
# 00:35:46,530 --> 00:35:51,210
# on the milling yourself included now I
#
# 839
# 00:35:48,420 --> 00:35:53,400
# want to talk about the revival of
#
# 840
# 00:35:51,210 --> 00:35:55,260
# interest in fraida after the Second
#
# 841
# 00:35:53,400 --> 00:35:56,940
# World War so that the interest in Frager
#
# 842
# 00:35:55,260 --> 00:36:00,480
# can be interested in Russell for the
#
# 843
# 00:35:56,940 --> 00:36:03,000
# first time proceed side by side into the
#
# 844
# 00:36:00,480 --> 00:36:05,250
# age that we now live in it's very
#
# 845
# 00:36:03,000 --> 00:36:08,240
# difficult to account for historical
#
# 846
# 00:36:05,250 --> 00:36:11,420
# events particularly in such short of
#
# 847
# 00:36:08,240 --> 00:36:14,369
# perspective and the Attic see if the
#
# 848
# 00:36:11,420 --> 00:36:17,040
# certainly was in immediate reward
#
# 849
# 00:36:14,369 --> 00:36:19,109
# decline in Russell's insolence in high
#
# 850
# 00:36:17,040 --> 00:36:25,130
# earnings only and this is addict knock
#
# 851
# 00:36:19,109 --> 00:36:27,599
# you to revival register Sega but to an
#
# 852
# 00:36:25,130 --> 00:36:30,450
# increased importance attached to the
#
# 853
# 00:36:27,599 --> 00:36:32,400
# work of Vic and Stein and more in worst
#
# 854
# 00:36:30,450 --> 00:36:34,140
# case so I enormous li-like to infection
#
# 855
# 00:36:32,400 --> 00:36:37,920
# as a man I think philosophically it was
#
# 856
# 00:36:34,140 --> 00:36:40,290
# excessive and I think this was just to
#
# 857
# 00:36:37,920 --> 00:36:42,119
# the responsiveness for partly not a
#
# 858
# 00:36:40,290 --> 00:36:45,390
# trial who respected Russell but mainly
#
# 859
# 00:36:42,119 --> 00:36:47,369
# Austin who was the linguistic
#
# 860
# 00:36:45,390 --> 00:36:50,119
# philosopher and narrow as possible sense
#
# 861
# 00:36:47,369 --> 00:36:53,010
# and had a great respect for more as as
#
# 862
# 00:36:50,119 --> 00:36:54,869
# someone who - great importance tour
#
# 863
# 00:36:53,010 --> 00:36:56,640
# during his huges of the common sense and
#
# 864
# 00:36:54,869 --> 00:36:58,290
# so on common sense as said by Russell
#
# 865
# 00:36:56,640 --> 00:37:01,460
# incidentally the metaphysics of savages
#
# 866
# 00:36:58,290 --> 00:37:04,319
# and I think it was the upgrading of more
#
# 867
# 00:37:01,460 --> 00:37:06,270
# that was responsible for at that time to
#
# 868
# 00:37:04,319 --> 00:37:08,160
# downgrade Nebraska and this is it same
#
# 869
# 00:37:06,270 --> 00:37:10,440
# it's now been reversed I'm glad I say I
#
# 870
# 00:37:08,160 --> 00:37:12,060
# think you've got a bit too far in saying
#
# 871
# 00:37:10,440 --> 00:37:13,920
# Russell was downgraded because if one
#
# 872
# 00:37:12,060 --> 00:37:15,200
# thinks back to those post-war years it
#
# 873
# 00:37:13,920 --> 00:37:16,680
# takes now who were the major
#
# 874
# 00:37:15,200 --> 00:37:19,530
# philosophers in the english-speaking
#
# 875
# 00:37:16,680 --> 00:37:21,000
# world the shortest short lists would
#
# 876
# 00:37:19,530 --> 00:37:23,069
# have to include the parson Russell
#
# 877
# 00:37:21,000 --> 00:37:26,339
# himself Vidkun Stein
#
# 878
# 00:37:23,069 --> 00:37:29,069
# Karl Popper Quine Gilbert Ryle yourself
#
# 879
# 00:37:26,339 --> 00:37:29,640
# and all of you were massively influenced
#
# 880
# 00:37:29,069 --> 00:37:34,950
# by Russia
#
# 881
# 00:37:29,640 --> 00:37:36,030
# yes perhaps perhaps I'm I I mean yes so
#
# 882
# 00:37:34,950 --> 00:37:38,490
# you would know better than that because
#
# 883
# 00:37:36,030 --> 00:37:39,720
# you are sober up at Oxford have been in
#
# 884
# 00:37:38,490 --> 00:37:44,280
# the fifties and when I had already
#
# 885
# 00:37:39,720 --> 00:37:46,559
# departed them for the London certainly
#
# 886
# 00:37:44,280 --> 00:37:50,469
# the impression reaching is
#
# 887
# 00:37:46,559 --> 00:37:51,999
# well the brussels began taking an oxford
#
# 888
# 00:37:50,469 --> 00:37:54,069
# based view and i think that's mistaken
#
# 889
# 00:37:51,999 --> 00:37:55,630
# about the view I saw I think there were
#
# 890
# 00:37:54,069 --> 00:37:58,239
# other people around then who has
#
# 891
# 00:37:55,630 --> 00:38:00,069
# perished roughly perfectly true yes but
#
# 892
# 00:37:58,239 --> 00:38:03,279
# there were condemning for the landing
#
# 893
# 00:38:00,069 --> 00:38:07,209
# and John and very glad yes yes
#
# 894
# 00:38:03,279 --> 00:38:08,949
# and I certainly restless as recovered he
#
# 895
# 00:38:07,209 --> 00:38:11,229
# himself here the best time in forever I
#
# 896
# 00:38:08,949 --> 00:38:13,229
# can he himself boxes yeah cuz I was
#
# 897
# 00:38:11,229 --> 00:38:15,759
# seeing gradients dealing with the time I
#
# 898
# 00:38:13,229 --> 00:38:18,329
# organized the grouping Lauren in London
#
# 899
# 00:38:15,759 --> 00:38:21,640
# that he attended and he was certainly
#
# 900
# 00:38:18,329 --> 00:38:23,920
# miss kiss has to mal do heard but he
#
# 901
# 00:38:21,640 --> 00:38:27,130
# thought that he that he wasn't getting
#
# 902
# 00:38:23,920 --> 00:38:30,819
# his you and also lots of slack vein and
#
# 903
# 00:38:27,130 --> 00:38:32,619
# all and he disliked all in vain and we
#
# 904
# 00:38:30,819 --> 00:38:36,279
# agree in any case that that he's come
#
# 905
# 00:38:32,619 --> 00:38:38,559
# back he's come back now the revival of
#
# 906
# 00:38:36,279 --> 00:38:41,859
# figure is something that I really I
#
# 907
# 00:38:38,559 --> 00:38:44,319
# think him can't explain I don't even
#
# 908
# 00:38:41,859 --> 00:38:49,059
# know exactly how it happened
#
# 909
# 00:38:44,319 --> 00:38:52,449
# probably it started in America with the
#
# 910
# 00:38:49,059 --> 00:38:55,329
# development of suitable additions led by
#
# 911
# 00:38:52,449 --> 00:38:57,369
# a man called Alonzo Church who insisted
#
# 912
# 00:38:55,329 --> 00:38:59,170
# on very great rigor in lodged in
#
# 913
# 00:38:57,369 --> 00:39:01,150
# mathematics and found in Sager and
#
# 914
# 00:38:59,170 --> 00:39:02,829
# didn't find it in in Russell and
#
# 915
# 00:39:01,150 --> 00:39:04,569
# Whitehead so of course they did find
#
# 916
# 00:39:02,829 --> 00:39:05,920
# elsewhere the finest example Gilbert
#
# 917
# 00:39:04,569 --> 00:39:11,289
# where a dispute over for other reasons
#
# 918
# 00:39:05,920 --> 00:39:13,779
# and in England it seems shall been the
#
# 919
# 00:39:11,289 --> 00:39:17,109
# first evidence second plan of it isn't a
#
# 920
# 00:39:13,779 --> 00:39:20,170
# book published a fairly late about 96
#
# 921
# 00:39:17,109 --> 00:39:23,439
# planning by William ammonia which is a
#
# 922
# 00:39:20,170 --> 00:39:25,359
# very impressive history of logic in
#
# 923
# 00:39:23,439 --> 00:39:27,459
# which which very great importance is
#
# 924
# 00:39:25,359 --> 00:39:29,380
# given to Frager he's put on the level
#
# 925
# 00:39:27,459 --> 00:39:31,539
# with Aristotle he goes to great name and
#
# 926
# 00:39:29,380 --> 00:39:33,910
# then I don't know whatever one I come to
#
# 927
# 00:39:31,539 --> 00:39:35,920
# once again son behind me there was a
#
# 928
# 00:39:33,910 --> 00:39:38,829
# translation in the early fifties
#
# 929
# 00:39:35,920 --> 00:39:44,130
# nineteen fifty itself 9212 oh yeah they
#
# 930
# 00:39:38,829 --> 00:39:48,130
# are made by Austin of Sega's good login'
#
# 931
# 00:39:44,130 --> 00:39:52,479
# remember also translation made thirty
#
# 932
# 00:39:48,130 --> 00:39:55,989
# years later by Max back an Englishman
#
# 933
# 00:39:52,479 --> 00:39:59,670
# living work in America and by PT each of
#
# 934
# 00:39:55,989 --> 00:40:01,830
# two figures very obscure but in port
#
# 935
# 00:39:59,670 --> 00:40:04,110
# semantics essays one of them called
#
# 936
# 00:40:01,830 --> 00:40:07,200
# sense reference from the other called
#
# 937
# 00:40:04,110 --> 00:40:09,420
# function concept and so there was in the
#
# 938
# 00:40:07,200 --> 00:40:11,940
# entities the sudden interest in Vega but
#
# 939
# 00:40:09,420 --> 00:40:14,820
# I'm not quite certain what led to it
#
# 940
# 00:40:11,940 --> 00:40:17,160
# Oh Angie what Constance is dead well a
#
# 941
# 00:40:14,820 --> 00:40:18,990
# lot of very bright younger people took
#
# 942
# 00:40:17,160 --> 00:40:21,510
# it up didn't they and were influenced by
#
# 943
# 00:40:18,990 --> 00:40:22,830
# it whether that'll last or what I don't
#
# 944
# 00:40:21,510 --> 00:40:24,600
# know but it certainly seems to be
#
# 945
# 00:40:22,830 --> 00:40:27,270
# something going on which I find very
#
# 946
# 00:40:24,600 --> 00:40:29,040
# little influence of Vega incurrence
#
# 947
# 00:40:27,270 --> 00:40:31,410
# result we work apart from the work of
#
# 948
# 00:40:29,040 --> 00:40:35,040
# damnit who if we look at the term
#
# 949
# 00:40:31,410 --> 00:40:36,270
# planning now perhaps some of the most
#
# 950
# 00:40:35,040 --> 00:40:37,860
# interesting we have being done is being
#
# 951
# 00:40:36,270 --> 00:40:40,890
# done in America and if you look at the
#
# 952
# 00:40:37,860 --> 00:40:45,600
# work of people like wine and platinum
#
# 953
# 00:40:40,890 --> 00:40:47,880
# and and Thomas Nagel and and Donald
#
# 954
# 00:40:45,600 --> 00:40:50,250
# Davidson in particular you don't find
#
# 955
# 00:40:47,880 --> 00:40:53,700
# cyst on inputs of Vega
#
# 956
# 00:40:50,250 --> 00:40:57,810
# except pepsin Davidson's case indirectly
#
# 957
# 00:40:53,700 --> 00:41:01,020
# through the works of from the position
#
# 958
# 00:40:57,810 --> 00:41:03,330
# tarski onto which edge links a created
#
# 959
# 00:41:01,020 --> 00:41:05,310
# by the Vega link himself link meaning in
#
# 960
# 00:41:03,330 --> 00:41:09,960
# groups are you confident with the
#
# 961
# 00:41:05,310 --> 00:41:12,690
# influence of Russia will last yes you
#
# 962
# 00:41:09,960 --> 00:41:14,280
# are why why so because I think because
#
# 963
# 00:41:12,690 --> 00:41:16,710
# there because that is a who I think it
#
# 964
# 00:41:14,280 --> 00:41:18,900
# was reading that that the questions he
#
# 965
# 00:41:16,710 --> 00:41:21,720
# asks are the important result for
#
# 966
# 00:41:18,900 --> 00:41:24,360
# questions and I think that he is answers
#
# 967
# 00:41:21,720 --> 00:41:25,770
# to them whether right or wrong will
#
# 968
# 00:41:24,360 --> 00:41:28,380
# always be to be taken into consideration
#
# 969
# 00:41:25,770 --> 00:41:29,940
# and if I'm right about you to you also
#
# 970
# 00:41:28,380 --> 00:41:32,640
# think that he's approached his
#
# 971
# 00:41:29,940 --> 00:41:34,970
# conception of what philosophy is is the
#
# 972
# 00:41:32,640 --> 00:41:38,120
# right conception yes but it consists of
#
# 973
# 00:41:34,970 --> 00:41:41,010
# clarification there for analysis and
#
# 974
# 00:41:38,120 --> 00:41:42,240
# justification there for argument about
#
# 975
# 00:41:41,010 --> 00:41:44,970
# importantly
#
# 976
# 00:41:42,240 --> 00:41:47,720
# written in straightforward English prose
#
# 977
# 00:41:44,970 --> 00:41:50,550
# oh well not English written in business
#
# 978
# 00:41:47,720 --> 00:41:54,170
# in straightforward prior straightforward
#
# 979
# 00:41:50,550 --> 00:41:56,340
# ways thank you very much professor
#
# 980
# 00:41:54,170 --> 00:41:58,050
# okay that's all that was splendid I
#
# 981
# 00:41:56,340 --> 00:42:01,280
# thought it was better many of our
#
# 982
# 00:41:58,050 --> 00:42:01,280
# mantras oh good
#
# 983
# 00:42:03,460 --> 00:42:05,520
# you

# %%
type(srt_captions)
# Out:
# str

# %% [markdown]
# So the generate_srt_captions just generates a long string. But you can use the XML to get individual timings.
#
# It's interesting that the captions last for about 4 seconds and contain multiple words. Also no punctuation.

# %% [markdown]
# ## Multiple Videos
#
# One thing we can do quickly is create a playlist and use that - https://python-pytube.readthedocs.io/en/latest/user/playlist.html.

# %% [markdown]
# ### Searching
#
# You can use the YouTube http search and a wrapper such as urllib - https://codefather.tech/blog/youtube-search-python/.
#
# Or the official python youtube URI - https://developers.google.com/youtube/v3/quickstart/python.
#
# Also check out this tutorial - https://towardsdatascience.com/automatic-speech-recognition-data-collection-with-youtube-v3-api-mask-rcnn-and-google-vision-api-2370d6776109.

# %% [markdown]
# To stream rather than download you can extract YouTube urls and pass to a command line media player using SubProcess - https://stackoverflow.com/questions/49354232/how-to-stream-audio-from-a-youtube-url-in-python-without-download.
#
# The main command line media players are MPV or VLC.
# * There are Python bindings for both MPV - https://github.com/jaseg/python-mpv
# * VLC - https://linuxconfig.org/how-to-play-audio-with-vlc-in-python

# %% [markdown]
# # Summary
#
# The easiest way to go is to find or create a playlist with days of captioned videos, then to download video, audio and captions, then to process.
#
# This will, though, take up a lot of space (we might need an external hard drive). But setting up a streaming wrapper will take a LOT more effort.
